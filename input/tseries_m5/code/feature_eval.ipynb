# %% [markdown]
# <a href="https://colab.research.google.com/github/arita37/time/blob/master/feature_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd 'drive'
# Out:
# /content/drive

# %%
# %cd 'My Drive/Upwork'
# Out:
# /content/drive/My Drive/Upwork

# %%
import numpy as np
import pandas as pd

import time

import os
import matplotlib.pyplot as plt
plt.style.use("dark_background")
import seaborn as sns

# Time series analysis
import statsmodels.api as sm
from pandas.plotting import autocorrelation_plot

# Data preprocessing
from sklearn.model_selection import train_test_split

# Library
import lightgbm as lgb

# Grid search
from sklearn.model_selection import GridSearchCV

# Validataion
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
train_df = pd.read_csv("sales_train_validation.csv")
calendar_df = pd.read_csv("calendar.csv")
price_df = pd.read_csv("sell_prices.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
calendar_df["date_dt"] = pd.to_datetime(calendar_df["date"])

# %%
print("train data:{}".format(train_df.shape))
print("calendar data:{}".format(calendar_df.shape))
print("price data:{}".format(price_df.shape))
print("sample data:{}".format(sample.shape))
# Out:
# train data:(30490, 1919)
# calendar data:(1969, 15)
# price data:(6841121, 4)
# sample data:(60980, 29)

# %%
train  = train_df.copy()
price = price_df.copy()
calendar = calendar_df.copy()

# %%
def lag_featrues(df):
    out_df = df[['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']]
    ###############################################################################
    # day lag 29~57 day and last year's day lag 1~28 day 
    day_lag = df.iloc[:,-28:]
    day_year_lag = df.iloc[:,-393:-365]
    day_lag.columns = [str("lag_{}_day".format(i)) for i in range(29,57)] # Rename columns
    day_year_lag.columns = [str("lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    
    # Rolling mean(3) and (7) and (28) and (84) 29~57 day and last year's day lag 1~28 day 
    rolling_3 = df.iloc[:,-730:].T.rolling(3).mean().T.iloc[:,-28:]
    rolling_3.columns = [str("rolling3_lag_{}_day".format(i)) for i in range(29,57)] # Rename columns
    rolling_3_year = df.iloc[:,-730:].T.rolling(3).mean().T.iloc[:,-393:-365]
    rolling_3_year.columns = [str("rolling3_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    
    rolling_7 = df.iloc[:,-730:].T.rolling(7).mean().T.iloc[:,-28:]
    rolling_7.columns = [str("rolling7_lag_{}_day".format(i)) for i in range(29,57)] # Rename columns
    rolling_7_year = df.iloc[:,-730:].T.rolling(7).mean().T.iloc[:,-393:-365]
    rolling_7_year.columns = [str("rolling7_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    
    rolling_28 = df.iloc[:,-730:].T.rolling(28).mean().T.iloc[:,-28:]
    rolling_28.columns = [str("rolling28_lag_{}_day".format(i)) for i in range(29,57)]
    rolling_28_year = df.iloc[:,-730:].T.rolling(28).mean().T.iloc[:,-393:-365]
    rolling_28_year.columns = [str("rolling28_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    
    rolling_84 = df.iloc[:,-730:].T.rolling(84).mean().T.iloc[:,-28:]
    rolling_84.columns = [str("rolling84_lag_{}_day".format(i)) for i in range(29,57)]
    rolling_84_year = df.iloc[:,-730:].T.rolling(84).mean().T.iloc[:,-393:-365]
    rolling_84_year.columns = [str("rolling84_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    
    # monthly lag 1~18 month
    month_lag = pd.DataFrame({})
    for i in range(1,19):
        if i == 1:
            monthly = df.iloc[:,-28*i:].T.sum().T
            month_lag["monthly_lag_{}_month".format(i)] = monthly
        else:
            monthly = df.iloc[:, -28*i:-28*(i-1)].T.sum().T
            month_lag["monthly_lag_{}_month".format(i)] = monthly
            
    # combine day lag and monthly lag
    out_df = pd.concat([out_df, day_lag], axis=1)
    out_df = pd.concat([out_df, day_year_lag], axis=1)
    out_df = pd.concat([out_df, rolling_3], axis=1)
    out_df = pd.concat([out_df, rolling_3_year], axis=1)
    out_df = pd.concat([out_df, rolling_7], axis=1)
    out_df = pd.concat([out_df, rolling_7_year], axis=1)
    out_df = pd.concat([out_df, rolling_28], axis=1)
    out_df = pd.concat([out_df, rolling_28_year], axis=1)
    out_df = pd.concat([out_df, rolling_84], axis=1)
    out_df = pd.concat([out_df, rolling_84_year], axis=1)
    out_df = pd.concat([out_df, month_lag], axis=1)
    
    ###############################################################################
    # dept_id
    group_dept = df.groupby("dept_id").sum()
    # day lag 29~57 day and last year's day lag 1~28 day 
    dept_day_lag = group_dept.iloc[:,-28:]
    dept_day_year_lag = group_dept.iloc[:,-393:-365]
    dept_day_lag.columns = [str("dept_lag_{}_day".format(i)) for i in range(29,57)]
    dept_day_year_lag.columns = [str("dept_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    # monthly lag 1~18 month
    month_dept_lag = pd.DataFrame({})
    for i in range(1,19):
        if i == 1:
            monthly_dept = group_dept.iloc[:,-28*i:].T.sum().T
            month_dept_lag["dept_monthly_lag_{}_month".format(i)] = monthly_dept
        elif i >= 7 and i < 13:
            continue
        else:
            monthly = group_dept.iloc[:, -28*i:-28*(i-1)].T.sum().T
            month_dept_lag["dept_monthly_lag_{}_month".format(i)] = monthly_dept
    # combine out df
    out_df = pd.merge(out_df, dept_day_lag, left_on="dept_id", right_index=True, how="left")
    out_df = pd.merge(out_df, dept_day_year_lag, left_on="dept_id", right_index=True, how="left")
    out_df = pd.merge(out_df, month_dept_lag, left_on="dept_id", right_index=True, how="left")
    
    ###############################################################################       
    # cat_id
    group_cat = df.groupby("cat_id").sum()
    # day lag 29~57 day and last year's day lag 1~28 day 
    cat_day_lag = group_cat.iloc[:,-28:]
    cat_day_year_lag = group_cat.iloc[:,-393:-365]
    cat_day_lag.columns = [str("cat_lag_{}_day".format(i)) for i in range(29,57)]
    cat_day_year_lag.columns = [str("cat_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    # monthly lag 1~18 month
    month_cat_lag = pd.DataFrame({})
    for i in range(1,19):
        if i == 1:
            monthly_cat = group_cat.iloc[:,-28*i:].T.sum().T
            month_cat_lag["cat_monthly_lag_{}_month".format(i)] = monthly_cat
        elif i >= 7 and i < 13:
            continue
        else:
            monthly_cat = group_cat.iloc[:, -28*i:-28*(i-1)].T.sum().T
            month_cat_lag["dept_monthly_lag_{}_month".format(i)] = monthly_cat
            
    # combine out df
    out_df = pd.merge(out_df, cat_day_lag, left_on="cat_id", right_index=True, how="left")
    out_df = pd.merge(out_df, cat_day_year_lag, left_on="cat_id", right_index=True, how="left")
    out_df = pd.merge(out_df, month_cat_lag, left_on="cat_id", right_index=True, how="left")
    
    ###############################################################################
    # store_id
    group_store = df.groupby("store_id").sum()
    # day lag 29~57 day and last year's day lag 1~28 day 
    store_day_lag = group_store.iloc[:,-28:]
    store_day_year_lag = group_store.iloc[:,-393:-365]
    store_day_lag.columns = [str("store_lag_{}_day".format(i)) for i in range(29,57)]
    store_day_year_lag.columns = [str("store_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    # monthly lag 1~18 month
    month_store_lag = pd.DataFrame({})
    for i in range(1,19):
        if i == 1:
            monthly_store = group_store.iloc[:,-28*i:].T.sum().T
            month_store_lag["store_monthly_lag_{}_month".format(i)] = monthly_store
        elif i >= 7 and i <13:
            continue
        else:
            monthly_store = group_store.iloc[:, -28*i:-28*(i-1)].T.sum().T
            month_store_lag["store_monthly_lag_{}_month".format(i)] = monthly_store
            
    # combine out df
    out_df = pd.merge(out_df, store_day_lag, left_on="store_id", right_index=True, how="left")
    out_df = pd.merge(out_df, store_day_year_lag, left_on="store_id", right_index=True, how="left")
    out_df = pd.merge(out_df, month_store_lag, left_on="store_id", right_index=True, how="left")
    
    ###############################################################################
    # state_id
    group_state = df.groupby("state_id").sum()
    # day lag 29~57 day and last year's day lag 1~28 day 
    state_day_lag = group_state.iloc[:,-28:]
    state_day_year_lag = group_state.iloc[:,-393:-365]
    state_day_lag.columns = [str("state_lag_{}_day".format(i)) for i in range(29,57)]
    state_day_year_lag.columns = [str("state_lag_{}_day_of_last_year".format(i)) for i in range(1,29)]
    # monthly lag 1~18 month
    month_state_lag = pd.DataFrame({})
    for i in range(1,13):
        if i == 1:
            monthly_state = group_state.iloc[:,-28*i:].T.sum().T
            month_state_lag["state_monthly_lag_{}_month".format(i)] = monthly_state
        elif i >= 7 and i < 13:
            continue
        else:
            monthly_state = group_state.iloc[:, -28*i:-28*(i-1)].T.sum().T
            month_state_lag["state_monthly_lag_{}_month".format(i)] = monthly_state
            
    # combine out df
    out_df = pd.merge(out_df, state_day_lag, left_on="state_id", right_index=True, how="left")
    out_df = pd.merge(out_df, state_day_year_lag, left_on="state_id", right_index=True, how="left")
    out_df = pd.merge(out_df, month_state_lag, left_on="state_id", right_index=True, how="left")
    
    ###############################################################################
    # category flag
    col_list = ['dept_id', 'cat_id', 'store_id', 'state_id']
    
    df_cate_oh = pd.DataFrame({})
    for i in col_list:
        df_oh = pd.get_dummies(df[i])
        df_cate_oh = pd.concat([df_cate_oh, df_oh], axis=1)
        
    out_df = pd.concat([out_df, df_cate_oh], axis=1)
    
    return out_df

# %%
import pandas as pd

#df_metrics.to_csv("eval_stats.csv", sep="\t")
#df_metrics.head()
df_metrics={'run_id':[], 'feat_name':[], "feat_name_long":[], "feat_type":[], "model_params":[], "metric_name":[], "metric_val":[]}
df_metrics = pd.DataFrame(data=df_metrics)
df_metrics.columns
# Out:
# Index(['run_id', 'feat_name', 'feat_name_long', 'feat_type', 'model_params',
#        'metric_name', 'metric_val'],
#       dtype='object')

# %%
# Features
Train_data = train.iloc[:,:-56]
Val_data = train.iloc[:,:-28]
pred=[]
X_train = lag_featrues(Train_data).iloc[:,5:] # select variables
y_train = train.iloc[:,-56]
X_test = lag_featrues(Val_data).iloc[:,5:]
y_test = train.iloc[:,-28]

# Create instance
lgbm = lgb.LGBMRegressor()

# Training and score
learning_rate = [0.15, 0.2, 0.25]
max_depth = [15, 20, 25]

param_grid = {'learning_rate': learning_rate, 'max_depth': max_depth}
param=param_grid
#df_metrics.model_params=max_depth
# Fitting
cv_lgbm = GridSearchCV(lgbm, param_grid, cv=10, n_jobs =1)
cv_lgbm.fit(X_train, y_train)

print("Best params:{}".format(cv_lgbm.best_params_))

# best params
best_lg = cv_lgbm.best_estimator_

# prediction
y_train_pred_lg = best_lg.predict(X_train)
y_test_pred_lg = best_lg.predict(X_test)

print("MSE train:{}".format(mean_squared_error(y_train, y_train_pred_lg)))
print("MSE test;{}".format(mean_squared_error(y_test, y_test_pred_lg)))
pred_mse=y_train_pred_lg
print("R2 score train:{}".format(r2_score(y_train, y_train_pred_lg)))
pred_rmse=y_train_pred_lg
print("R2 score test:{}".format(r2_score(y_test, y_test_pred_lg)))
df_metrics.metric_name="RMSE"
# Out:
# Best params:{'learning_rate': 0.15, 'max_depth': 15}
# MSE train:1.092012714799604
# MSE test;3.3766285234516995
# R2 score train:0.880892037264018
# R2 score test:0.6074382220106134

# %%
#best_lg="boosting_type='gbdt',learning_rate=0.15,"

#dataframe['parameter'] = X_train.columns

# %%
#Predict using only variables with an importance of 1 or higher.
importance = best_lg.feature_importances_

indices = np.argsort(importance)[::-1]

# print importance
importance_df = pd.DataFrame({})
columns = []
importance_ = []
for f in range(X_train.shape[1]):
    print("%2d) %-*s %.2f" %(f+1, 30, X_train.columns[indices[f]], importance[indices[f]]))
    col = X_train.columns[indices[f]]
    imp = importance[indices[f]]
    columns.append(col)
    importance_.append(imp)
importance_df["col_name"] = columns
importance_df["importance"] = importance_
importance = best_lg.feature_importances_

indices = np.argsort(importance)[::-1]
# Out:
#  1) lag_44_day                     74.00
#  2) rolling3_lag_56_day            65.00
#  3) rolling7_lag_56_day            43.00
#  4) lag_56_day                     40.00
#  5) rolling3_lag_46_day            34.00
#  6) rolling3_lag_33_day            33.00
#  7) lag_32_day                     32.00
#  8) lag_33_day                     32.00
#  9) monthly_lag_10_month           30.00
# 10) rolling28_lag_56_day           29.00
# 11) lag_55_day                     29.00
# 12) lag_54_day                     29.00
# 13) rolling3_lag_51_day            28.00
# 14) monthly_lag_3_month            28.00
# 15) rolling3_lag_45_day            28.00
# 16) monthly_lag_8_month            26.00
# 17) lag_29_day                     25.00
# 18) monthly_lag_18_month           24.00
# 19) rolling3_lag_47_day            24.00
# 20) lag_34_day                     24.00
# 21) monthly_lag_7_month            24.00
# 22) rolling3_lag_44_day            23.00
# 23) lag_43_day                     23.00
# 24) rolling3_lag_52_day            23.00
# 25) monthly_lag_11_month           22.00
# 26) lag_37_day                     21.00
# 27) monthly_lag_17_month           21.00
# 28) monthly_lag_13_month           21.00
# 29) rolling7_lag_29_day            20.00
# 30) lag_30_day                     20.00
# 31) rolling3_lag_36_day            20.00
# 32) lag_31_day                     19.00
# 33) rolling3_lag_31_day            19.00
# 34) rolling7_lag_54_day            19.00
# 35) monthly_lag_6_month            19.00
# 36) rolling3_lag_54_day            19.00
# 37) lag_42_day                     19.00
# 38) lag_8_day_of_last_year         19.00
# 39) lag_51_day                     19.00
# 40) rolling3_lag_34_day            18.00
# 41) store_lag_29_day               18.00
# 42) lag_50_day                     18.00
# 43) lag_38_day                     18.00
# 44) rolling3_lag_55_day            18.00
# 45) lag_49_day                     18.00
# 46) rolling3_lag_53_day            18.00
# 47) lag_23_day_of_last_year        17.00
# 48) lag_48_day                     17.00
# 49) lag_20_day_of_last_year        17.00
# 50) monthly_lag_4_month            17.00
# 51) lag_41_day                     17.00
# 52) lag_47_day                     17.00
# 53) rolling3_lag_38_day            17.00
# 54) rolling3_lag_48_day            16.00
# 55) lag_52_day                     16.00
# 56) rolling3_lag_29_day            16.00
# 57) rolling7_lag_31_day            16.00
# 58) rolling3_lag_35_day            16.00
# 59) lag_9_day_of_last_year         16.00
# 60) rolling3_lag_24_day_of_last_year 16.00
# 61) rolling7_lag_30_day            16.00
# 62) rolling7_lag_1_day_of_last_year 15.00
# 63) rolling3_lag_39_day            15.00
# 64) rolling7_lag_51_day            15.00
# 65) monthly_lag_16_month           15.00
# 66) lag_4_day_of_last_year         15.00
# 67) lag_13_day_of_last_year        14.00
# 68) lag_28_day_of_last_year        14.00
# 69) rolling3_lag_49_day            14.00
# 70) rolling3_lag_50_day            14.00
# 71) rolling7_lag_28_day_of_last_year 14.00
# 72) rolling7_lag_38_day            13.00
# 73) rolling7_lag_48_day            13.00
# 74) monthly_lag_12_month           13.00
# 75) monthly_lag_9_month            13.00
# 76) lag_46_day                     13.00
# 77) rolling3_lag_43_day            13.00
# 78) lag_39_day                     12.00
# 79) rolling3_lag_27_day_of_last_year 12.00
# 80) lag_1_day_of_last_year         12.00
# 81) lag_3_day_of_last_year         12.00
# 82) lag_7_day_of_last_year         12.00
# 83) monthly_lag_5_month            12.00
# 84) lag_18_day_of_last_year        12.00
# 85) lag_21_day_of_last_year        12.00
# 86) lag_25_day_of_last_year        12.00
# 87) lag_26_day_of_last_year        12.00
# 88) lag_27_day_of_last_year        12.00
# 89) rolling7_lag_50_day            12.00
# 90) rolling7_lag_37_day            12.00
# 91) rolling3_lag_40_day            12.00
# 92) rolling3_lag_41_day            12.00
# 93) rolling3_lag_30_day            12.00
# 94) rolling3_lag_16_day_of_last_year 12.00
# 95) rolling3_lag_11_day_of_last_year 12.00
# 96) rolling3_lag_12_day_of_last_year 12.00
# 97) rolling3_lag_14_day_of_last_year 12.00
# 98) rolling3_lag_1_day_of_last_year 11.00
# 99) lag_53_day                     11.00
# 100) rolling3_lag_3_day_of_last_year 11.00
# 101) lag_6_day_of_last_year         11.00
# 102) lag_17_day_of_last_year        11.00
# 103) rolling7_lag_10_day_of_last_year 11.00
# 104) rolling7_lag_2_day_of_last_year 11.00
# 105) rolling3_lag_28_day_of_last_year 11.00
# 106) rolling3_lag_42_day            11.00
# 107) rolling3_lag_5_day_of_last_year 11.00
# 108) rolling3_lag_23_day_of_last_year 11.00
# 109) rolling7_lag_33_day            11.00
# 110) rolling7_lag_34_day            11.00
# 111) rolling7_lag_35_day            11.00
# 112) rolling7_lag_42_day            11.00
# 113) rolling3_lag_32_day            11.00
# 114) rolling7_lag_26_day_of_last_year 10.00
# 115) lag_40_day                     10.00
# 116) lag_5_day_of_last_year         10.00
# 117) lag_14_day_of_last_year        10.00
# 118) rolling7_lag_36_day            10.00
# 119) rolling3_lag_15_day_of_last_year 10.00
# 120) monthly_lag_2_month            10.00
# 121) lag_35_day                     10.00
# 122) rolling7_lag_44_day            10.00
# 123) rolling7_lag_47_day            10.00
# 124) rolling7_lag_43_day            10.00
# 125) rolling7_lag_49_day            10.00
# 126) rolling3_lag_19_day_of_last_year 10.00
# 127) rolling3_lag_17_day_of_last_year 10.00
# 128) rolling3_lag_18_day_of_last_year 10.00
# 129) rolling7_lag_53_day            10.00
# 130) rolling7_lag_15_day_of_last_year 9.00
# 131) rolling7_lag_52_day            9.00
# 132) rolling3_lag_21_day_of_last_year 9.00
# 133) lag_10_day_of_last_year        9.00
# 134) lag_16_day_of_last_year        9.00
# 135) rolling3_lag_20_day_of_last_year 9.00
# 136) rolling3_lag_13_day_of_last_year 9.00
# 137) lag_36_day                     9.00
# 138) rolling7_lag_3_day_of_last_year 9.00
# 139) rolling7_lag_6_day_of_last_year 9.00
# 140) rolling28_lag_37_day           9.00
# 141) rolling7_lag_45_day            9.00
# 142) lag_24_day_of_last_year        9.00
# 143) monthly_lag_14_month           9.00
# 144) lag_12_day_of_last_year        8.00
# 145) rolling3_lag_25_day_of_last_year 8.00
# 146) rolling28_lag_1_day_of_last_year 8.00
# 147) lag_45_day                     8.00
# 148) rolling7_lag_13_day_of_last_year 8.00
# 149) rolling7_lag_4_day_of_last_year 8.00
# 150) rolling3_lag_37_day            8.00
# 151) dept_lag_29_day                8.00
# 152) rolling7_lag_39_day            8.00
# 153) rolling7_lag_55_day            8.00
# 154) rolling28_lag_34_day           8.00
# 155) store_lag_35_day               8.00
# 156) rolling28_lag_50_day           7.00
# 157) rolling84_lag_31_day           7.00
# 158) lag_15_day_of_last_year        7.00
# 159) rolling3_lag_7_day_of_last_year 7.00
# 160) rolling84_lag_56_day           7.00
# 161) rolling28_lag_30_day           7.00
# 162) rolling7_lag_11_day_of_last_year 7.00
# 163) rolling28_lag_48_day           7.00
# 164) rolling3_lag_10_day_of_last_year 7.00
# 165) rolling7_lag_46_day            7.00
# 166) cat_lag_29_day                 7.00
# 167) rolling7_lag_40_day            7.00
# 168) rolling3_lag_8_day_of_last_year 6.00
# 169) rolling3_lag_22_day_of_last_year 6.00
# 170) rolling3_lag_9_day_of_last_year 6.00
# 171) rolling7_lag_24_day_of_last_year 6.00
# 172) rolling84_lag_52_day           6.00
# 173) lag_11_day_of_last_year        6.00
# 174) rolling7_lag_22_day_of_last_year 6.00
# 175) rolling28_lag_25_day_of_last_year 6.00
# 176) rolling3_lag_4_day_of_last_year 6.00
# 177) rolling28_lag_29_day           6.00
# 178) rolling28_lag_54_day           6.00
# 179) rolling28_lag_35_day           6.00
# 180) rolling28_lag_49_day           6.00
# 181) rolling7_lag_16_day_of_last_year 5.00
# 182) rolling28_lag_33_day           5.00
# 183) rolling84_lag_1_day_of_last_year 5.00
# 184) rolling7_lag_17_day_of_last_year 5.00
# 185) rolling28_lag_53_day           5.00
# 186) rolling7_lag_7_day_of_last_year 5.00
# 187) rolling7_lag_8_day_of_last_year 5.00
# 188) rolling7_lag_18_day_of_last_year 5.00
# 189) rolling28_lag_47_day           5.00
# 190) rolling3_lag_26_day_of_last_year 5.00
# 191) rolling7_lag_32_day            5.00
# 192) rolling28_lag_42_day           5.00
# 193) lag_19_day_of_last_year        5.00
# 194) rolling28_lag_40_day           5.00
# 195) rolling28_lag_32_day           5.00
# 196) rolling3_lag_6_day_of_last_year 5.00
# 197) lag_2_day_of_last_year         5.00
# 198) rolling7_lag_23_day_of_last_year 5.00
# 199) rolling28_lag_12_day_of_last_year 5.00
# 200) rolling84_lag_29_day           5.00
# 201) rolling28_lag_3_day_of_last_year 4.00
# 202) rolling28_lag_10_day_of_last_year 4.00
# 203) store_lag_21_day_of_last_year  4.00
# 204) rolling28_lag_36_day           4.00
# 205) rolling28_lag_44_day           4.00
# 206) store_lag_48_day               4.00
# 207) rolling7_lag_25_day_of_last_year 4.00
# 208) store_lag_6_day_of_last_year   4.00
# 209) rolling7_lag_5_day_of_last_year 4.00
# 210) rolling84_lag_32_day           4.00
# 211) HOUSEHOLD_1                    4.00
# 212) rolling7_lag_9_day_of_last_year 4.00
# 213) rolling7_lag_21_day_of_last_year 4.00
# 214) rolling84_lag_44_day           4.00
# 215) rolling7_lag_12_day_of_last_year 4.00
# 216) rolling28_lag_9_day_of_last_year 4.00
# 217) rolling84_lag_10_day_of_last_year 4.00
# 218) rolling7_lag_14_day_of_last_year 4.00
# 219) store_lag_31_day               4.00
# 220) rolling7_lag_41_day            4.00
# 221) rolling28_lag_31_day           4.00
# 222) rolling7_lag_19_day_of_last_year 4.00
# 223) rolling28_lag_15_day_of_last_year 3.00
# 224) rolling84_lag_20_day_of_last_year 3.00
# 225) dept_lag_39_day                3.00
# 226) rolling28_lag_41_day           3.00
# 227) rolling28_lag_43_day           3.00
# 228) store_lag_40_day               3.00
# 229) store_lag_49_day               3.00
# 230) rolling28_lag_14_day_of_last_year 3.00
# 231) rolling84_lag_7_day_of_last_year 3.00
# 232) rolling28_lag_6_day_of_last_year 3.00
# 233) rolling84_lag_47_day           3.00
# 234) rolling3_lag_2_day_of_last_year 3.00
# 235) rolling28_lag_19_day_of_last_year 3.00
# 236) rolling28_lag_26_day_of_last_year 3.00
# 237) store_lag_1_day_of_last_year   3.00
# 238) rolling28_lag_23_day_of_last_year 2.00
# 239) store_lag_46_day               2.00
# 240) rolling28_lag_46_day           2.00
# 241) rolling84_lag_28_day_of_last_year 2.00
# 242) rolling28_lag_13_day_of_last_year 2.00
# 243) rolling84_lag_12_day_of_last_year 2.00
# 244) rolling28_lag_51_day           2.00
# 245) rolling28_lag_52_day           2.00
# 246) rolling28_lag_55_day           2.00
# 247) lag_22_day_of_last_year        2.00
# 248) rolling7_lag_27_day_of_last_year 2.00
# 249) rolling84_lag_17_day_of_last_year 2.00
# 250) rolling28_lag_2_day_of_last_year 2.00
# 251) rolling84_lag_34_day           2.00
# 252) rolling28_lag_4_day_of_last_year 2.00
# 253) rolling28_lag_5_day_of_last_year 2.00
# 254) rolling28_lag_7_day_of_last_year 2.00
# 255) rolling28_lag_8_day_of_last_year 2.00
# 256) rolling84_lag_41_day           2.00
# 257) store_lag_32_day               2.00
# 258) rolling28_lag_28_day_of_last_year 2.00
# 259) rolling7_lag_20_day_of_last_year 2.00
# 260) store_lag_42_day               2.00
# 261) rolling28_lag_39_day           2.00
# 262) dept_lag_12_day_of_last_year   2.00
# 263) rolling84_lag_50_day           2.00
# 264) rolling28_lag_38_day           2.00
# 265) rolling28_lag_20_day_of_last_year 2.00
# 266) rolling28_lag_24_day_of_last_year 2.00
# 267) rolling84_lag_43_day           2.00
# 268) rolling84_lag_55_day           2.00
# 269) rolling84_lag_54_day           2.00
# 270) rolling84_lag_33_day           1.00
# 271) store_lag_53_day               1.00
# 272) rolling84_lag_23_day_of_last_year 1.00
# 273) rolling28_lag_27_day_of_last_year 1.00
# 274) rolling84_lag_30_day           1.00
# 275) rolling84_lag_26_day_of_last_year 1.00
# 276) rolling84_lag_27_day_of_last_year 1.00
# 277) store_lag_5_day_of_last_year   1.00
# 278) dept_lag_25_day_of_last_year   1.00
# 279) store_lag_4_day_of_last_year   1.00
# 280) rolling84_lag_19_day_of_last_year 1.00
# 281) rolling84_lag_51_day           1.00
# 282) rolling84_lag_53_day           1.00
# 283) rolling84_lag_40_day           1.00
# 284) rolling84_lag_3_day_of_last_year 1.00
# 285) rolling84_lag_4_day_of_last_year 1.00
# 286) rolling84_lag_5_day_of_last_year 1.00
# 287) state_lag_35_day               1.00
# 288) store_lag_3_day_of_last_year   1.00
# 289) rolling84_lag_39_day           1.00
# 290) rolling84_lag_38_day           1.00
# 291) rolling84_lag_11_day_of_last_year 1.00
# 292) rolling84_lag_37_day           1.00
# 293) rolling84_lag_14_day_of_last_year 1.00
# 294) rolling84_lag_36_day           1.00
# 295) rolling84_lag_35_day           1.00
# 296) rolling84_lag_15_day_of_last_year 1.00
# 297) rolling84_lag_45_day           1.00
# 298) store_lag_9_day_of_last_year   1.00
# 299) HOBBIES_1                      1.00
# 300) TX_3                           1.00
# 301) FOODS_2                        1.00
# 302) state_lag_29_day               1.00
# 303) store_lag_56_day               1.00
# 304) TX_2                           1.00
# 305) store_lag_27_day_of_last_year  1.00
# 306) store_lag_39_day               1.00
# 307) store_lag_23_day_of_last_year  1.00
# 308) store_lag_33_day               1.00
# 309) rolling28_lag_17_day_of_last_year 1.00
# 310) store_lag_34_day               1.00
# 311) rolling28_lag_18_day_of_last_year 1.00
# 312) rolling28_lag_21_day_of_last_year 1.00
# 313) rolling28_lag_45_day           1.00
# 314) TX_1                           0.00
# 315) CA_3                           0.00
# 316) CA_4                           0.00
# 317) WI_1                           0.00
# 318) CA_1                           0.00
# 319) state_lag_22_day_of_last_year  0.00
# 320) WI_2                           0.00
# 321) WI_3                           0.00
# 322) CA                             0.00
# 323) state_lag_21_day_of_last_year  0.00
# 324) CA_2                           0.00
# 325) HOUSEHOLD_2                    0.00
# 326) HOUSEHOLD                      0.00
# 327) state_monthly_lag_6_month      0.00
# 328) state_lag_27_day_of_last_year  0.00
# 329) state_lag_26_day_of_last_year  0.00
# 330) state_lag_25_day_of_last_year  0.00
# 331) state_monthly_lag_2_month      0.00
# 332) state_monthly_lag_3_month      0.00
# 333) state_monthly_lag_4_month      0.00
# 334) state_monthly_lag_5_month      0.00
# 335) state_lag_24_day_of_last_year  0.00
# 336) HOBBIES                        0.00
# 337) state_lag_23_day_of_last_year  0.00
# 338) FOODS_1                        0.00
# 339) FOODS_3                        0.00
# 340) HOBBIES_2                      0.00
# 341) store_lag_2_day_of_last_year   0.00
# 342) state_lag_28_day_of_last_year  0.00
# 343) FOODS                          0.00
# 344) state_monthly_lag_1_month      0.00
# 345) state_lag_13_day_of_last_year  0.00
# 346) state_lag_20_day_of_last_year  0.00
# 347) state_lag_42_day               0.00
# 348) store_monthly_lag_5_month      0.00
# 349) state_lag_43_day               0.00
# 350) state_lag_44_day               0.00
# 351) store_monthly_lag_4_month      0.00
# 352) store_monthly_lag_3_month      0.00
# 353) store_monthly_lag_2_month      0.00
# 354) store_monthly_lag_1_month      0.00
# 355) store_lag_28_day_of_last_year  0.00
# 356) state_lag_45_day               0.00
# 357) store_lag_26_day_of_last_year  0.00
# 358) store_lag_25_day_of_last_year  0.00
# 359) store_lag_24_day_of_last_year  0.00
# 360) store_lag_22_day_of_last_year  0.00
# 361) state_lag_46_day               0.00
# 362) state_lag_47_day               0.00
# 363) store_monthly_lag_6_month      0.00
# 364) store_monthly_lag_13_month     0.00
# 365) state_lag_49_day               0.00
# 366) store_monthly_lag_14_month     0.00
# 367) state_lag_36_day               0.00
# 368) state_lag_34_day               0.00
# 369) state_lag_37_day               0.00
# 370) state_lag_38_day               0.00
# 371) state_lag_39_day               0.00
# 372) state_lag_40_day               0.00
# 373) state_lag_41_day               0.00
# 374) state_lag_33_day               0.00
# 375) state_lag_32_day               0.00
# 376) state_lag_31_day               0.00
# 377) state_lag_30_day               0.00
# 378) store_monthly_lag_18_month     0.00
# 379) store_monthly_lag_17_month     0.00
# 380) store_monthly_lag_16_month     0.00
# 381) store_monthly_lag_15_month     0.00
# 382) state_lag_48_day               0.00
# 383) state_lag_50_day               0.00
# 384) state_lag_19_day_of_last_year  0.00
# 385) state_lag_1_day_of_last_year   0.00
# 386) state_lag_3_day_of_last_year   0.00
# 387) state_lag_4_day_of_last_year   0.00
# 388) state_lag_5_day_of_last_year   0.00
# 389) state_lag_6_day_of_last_year   0.00
# 390) state_lag_7_day_of_last_year   0.00
# 391) state_lag_8_day_of_last_year   0.00
# 392) state_lag_9_day_of_last_year   0.00
# 393) state_lag_10_day_of_last_year  0.00
# 394) state_lag_11_day_of_last_year  0.00
# 395) state_lag_12_day_of_last_year  0.00
# 396) state_lag_14_day_of_last_year  0.00
# 397) state_lag_15_day_of_last_year  0.00
# 398) state_lag_16_day_of_last_year  0.00
# 399) state_lag_17_day_of_last_year  0.00
# 400) state_lag_18_day_of_last_year  0.00
# 401) state_lag_2_day_of_last_year   0.00
# 402) store_lag_7_day_of_last_year   0.00
# 403) store_lag_20_day_of_last_year  0.00
# 404) state_lag_56_day               0.00
# 405) store_lag_18_day_of_last_year  0.00
# 406) state_lag_51_day               0.00
# 407) store_lag_17_day_of_last_year  0.00
# 408) store_lag_16_day_of_last_year  0.00
# 409) store_lag_15_day_of_last_year  0.00
# 410) store_lag_14_day_of_last_year  0.00
# 411) state_lag_52_day               0.00
# 412) state_lag_53_day               0.00
# 413) store_lag_13_day_of_last_year  0.00
# 414) store_lag_12_day_of_last_year  0.00
# 415) store_lag_11_day_of_last_year  0.00
# 416) store_lag_10_day_of_last_year  0.00
# 417) state_lag_54_day               0.00
# 418) store_lag_8_day_of_last_year   0.00
# 419) state_lag_55_day               0.00
# 420) store_lag_19_day_of_last_year  0.00
# 421) store_lag_38_day               0.00
# 422) store_lag_55_day               0.00
# 423) cat_lag_38_day                 0.00
# 424) cat_lag_40_day                 0.00
# 425) cat_lag_41_day                 0.00
# 426) cat_lag_42_day                 0.00
# 427) cat_lag_43_day                 0.00
# 428) cat_lag_44_day                 0.00
# 429) cat_lag_45_day                 0.00
# 430) cat_lag_46_day                 0.00
# 431) cat_lag_47_day                 0.00
# 432) cat_lag_48_day                 0.00
# 433) cat_lag_49_day                 0.00
# 434) cat_lag_50_day                 0.00
# 435) cat_lag_51_day                 0.00
# 436) cat_lag_52_day                 0.00
# 437) cat_lag_53_day                 0.00
# 438) cat_lag_54_day                 0.00
# 439) cat_lag_55_day                 0.00
# 440) cat_lag_56_day                 0.00
# 441) cat_lag_39_day                 0.00
# 442) cat_lag_37_day                 0.00
# 443) cat_lag_2_day_of_last_year     0.00
# 444) cat_lag_36_day                 0.00
# 445) dept_monthly_lag_2_month_x     0.00
# 446) dept_monthly_lag_3_month_x     0.00
# 447) dept_monthly_lag_4_month_x     0.00
# 448) dept_monthly_lag_5_month_x     0.00
# 449) dept_monthly_lag_6_month_x     0.00
# 450) dept_monthly_lag_13_month_x    0.00
# 451) dept_monthly_lag_14_month_x    0.00
# 452) dept_monthly_lag_15_month_x    0.00
# 453) dept_monthly_lag_16_month_x    0.00
# 454) dept_monthly_lag_17_month_x    0.00
# 455) dept_monthly_lag_18_month_x    0.00
# 456) cat_lag_30_day                 0.00
# 457) cat_lag_31_day                 0.00
# 458) cat_lag_32_day                 0.00
# 459) cat_lag_33_day                 0.00
# 460) cat_lag_34_day                 0.00
# 461) cat_lag_35_day                 0.00
# 462) cat_lag_1_day_of_last_year     0.00
# 463) cat_lag_3_day_of_last_year     0.00
# 464) rolling28_lag_11_day_of_last_year 0.00
# 465) cat_lag_24_day_of_last_year    0.00
# 466) cat_lag_26_day_of_last_year    0.00
# 467) cat_lag_27_day_of_last_year    0.00
# 468) cat_lag_28_day_of_last_year    0.00
# 469) cat_monthly_lag_1_month        0.00
# 470) dept_monthly_lag_2_month_y     0.00
# 471) dept_monthly_lag_3_month_y     0.00
# 472) dept_monthly_lag_4_month_y     0.00
# 473) dept_monthly_lag_5_month_y     0.00
# 474) dept_monthly_lag_6_month_y     0.00
# 475) dept_monthly_lag_13_month_y    0.00
# 476) dept_monthly_lag_14_month_y    0.00
# 477) dept_monthly_lag_15_month_y    0.00
# 478) dept_monthly_lag_16_month_y    0.00
# 479) dept_monthly_lag_17_month_y    0.00
# 480) dept_monthly_lag_18_month_y    0.00
# 481) store_lag_30_day               0.00
# 482) store_lag_36_day               0.00
# 483) cat_lag_25_day_of_last_year    0.00
# 484) cat_lag_23_day_of_last_year    0.00
# 485) cat_lag_4_day_of_last_year     0.00
# 486) cat_lag_22_day_of_last_year    0.00
# 487) cat_lag_5_day_of_last_year     0.00
# 488) cat_lag_6_day_of_last_year     0.00
# 489) cat_lag_7_day_of_last_year     0.00
# 490) cat_lag_8_day_of_last_year     0.00
# 491) cat_lag_9_day_of_last_year     0.00
# 492) cat_lag_10_day_of_last_year    0.00
# 493) cat_lag_11_day_of_last_year    0.00
# 494) cat_lag_12_day_of_last_year    0.00
# 495) cat_lag_13_day_of_last_year    0.00
# 496) cat_lag_14_day_of_last_year    0.00
# 497) cat_lag_15_day_of_last_year    0.00
# 498) cat_lag_16_day_of_last_year    0.00
# 499) cat_lag_17_day_of_last_year    0.00
# 500) cat_lag_18_day_of_last_year    0.00
# 501) cat_lag_19_day_of_last_year    0.00
# 502) cat_lag_20_day_of_last_year    0.00
# 503) cat_lag_21_day_of_last_year    0.00
# 504) dept_monthly_lag_1_month       0.00
# 505) dept_lag_28_day_of_last_year   0.00
# 506) dept_lag_27_day_of_last_year   0.00
# 507) store_lag_54_day               0.00
# 508) store_lag_51_day               0.00
# 509) store_lag_50_day               0.00
# 510) store_lag_47_day               0.00
# 511) store_lag_45_day               0.00
# 512) store_lag_44_day               0.00
# 513) store_lag_43_day               0.00
# 514) TX                             0.00
# 515) monthly_lag_15_month           0.00
# 516) store_lag_41_day               0.00
# 517) dept_lag_30_day                0.00
# 518) dept_lag_31_day                0.00
# 519) dept_lag_32_day                0.00
# 520) dept_lag_33_day                0.00
# 521) dept_lag_34_day                0.00
# 522) dept_lag_35_day                0.00
# 523) dept_lag_36_day                0.00
# 524) dept_lag_37_day                0.00
# 525) store_lag_52_day               0.00
# 526) monthly_lag_1_month            0.00
# 527) dept_lag_26_day_of_last_year   0.00
# 528) rolling84_lag_25_day_of_last_year 0.00
# 529) rolling28_lag_16_day_of_last_year 0.00
# 530) rolling28_lag_22_day_of_last_year 0.00
# 531) store_lag_37_day               0.00
# 532) rolling84_lag_42_day           0.00
# 533) rolling84_lag_46_day           0.00
# 534) rolling84_lag_48_day           0.00
# 535) rolling84_lag_49_day           0.00
# 536) rolling84_lag_2_day_of_last_year 0.00
# 537) rolling84_lag_6_day_of_last_year 0.00
# 538) rolling84_lag_8_day_of_last_year 0.00
# 539) rolling84_lag_9_day_of_last_year 0.00
# 540) rolling84_lag_13_day_of_last_year 0.00
# 541) rolling84_lag_16_day_of_last_year 0.00
# 542) rolling84_lag_18_day_of_last_year 0.00
# 543) rolling84_lag_21_day_of_last_year 0.00
# 544) rolling84_lag_22_day_of_last_year 0.00
# 545) rolling84_lag_24_day_of_last_year 0.00
# 546) dept_lag_38_day                0.00
# 547) dept_lag_40_day                0.00
# 548) dept_lag_41_day                0.00
# 549) dept_lag_42_day                0.00
# 550) dept_lag_7_day_of_last_year    0.00
# 551) dept_lag_8_day_of_last_year    0.00
# 552) dept_lag_9_day_of_last_year    0.00
# 553) dept_lag_10_day_of_last_year   0.00
# 554) dept_lag_11_day_of_last_year   0.00
# 555) dept_lag_13_day_of_last_year   0.00
# 556) dept_lag_14_day_of_last_year   0.00
# 557) dept_lag_15_day_of_last_year   0.00
# 558) dept_lag_16_day_of_last_year   0.00
# 559) dept_lag_17_day_of_last_year   0.00
# 560) dept_lag_18_day_of_last_year   0.00
# 561) dept_lag_19_day_of_last_year   0.00
# 562) dept_lag_20_day_of_last_year   0.00
# 563) dept_lag_21_day_of_last_year   0.00
# 564) dept_lag_22_day_of_last_year   0.00
# 565) dept_lag_23_day_of_last_year   0.00
# 566) dept_lag_24_day_of_last_year   0.00
# 567) dept_lag_6_day_of_last_year    0.00
# 568) dept_lag_5_day_of_last_year    0.00
# 569) dept_lag_4_day_of_last_year    0.00
# 570) dept_lag_50_day                0.00
# 571) dept_lag_43_day                0.00
# 572) dept_lag_44_day                0.00
# 573) dept_lag_45_day                0.00
# 574) dept_lag_46_day                0.00
# 575) dept_lag_47_day                0.00
# 576) dept_lag_48_day                0.00
# 577) dept_lag_49_day                0.00
# 578) dept_lag_51_day                0.00
# 579) dept_lag_3_day_of_last_year    0.00
# 580) dept_lag_52_day                0.00
# 581) dept_lag_53_day                0.00
# 582) dept_lag_54_day                0.00
# 583) dept_lag_55_day                0.00
# 584) dept_lag_56_day                0.00
# 585) dept_lag_1_day_of_last_year    0.00
# 586) dept_lag_2_day_of_last_year    0.00
# 587) WI                             0.00

# %%
df_metrics=df_metrics[:366]
df_metrics
# Out:
# Empty DataFrame
# Columns: [run_id, feat_name, feat_name_long, feat_type, model_params, metric_name, metric_val]
# Index: []

# %%
X_train.columns[0:364]
df_metrics.feat_name
# Out:
# Series([], Name: feat_name, dtype: float64)

# %%
df_metrics.feat_name=X_train.columns[0:365]
df_metrics.metric_name="RMSE"
df_metrics.feat_type=df_metrics.feat_name
#df_metrics['feat_type'].replace(to_replace=r'^lag.$', value='hj', regex=True,inplace=True)
df_metrics.replace({'feat_type': r'^lag_.*'}, {'feat_type': 'lag'}, regex=True,inplace=True)
df_metrics.replace({'feat_type': r'^rolling_.*'}, {'feat_type': 'rolling'}, regex=True,inplace=True)
#indices=df_metrics.feat_name.str.find("lag")
#df_metrics["feat_type"]=df_metrics.feat_name.str.find("lag")
#df_metrics["feature_type"]=indices

# %%
# importance columns (>0)
imp_col = importance_df[importance_df["importance"]>0]["col_name"].values

# Train test split, select by imp_col

X_train = lag_featrues(Train_data).iloc[:,5:][imp_col] # select variables
y_train = train.iloc[:,-56]
X_test = lag_featrues(Val_data).iloc[:,5:][imp_col]
y_test = train.iloc[:,-28]

# Create instance
lgbm = lgb.LGBMRegressor()

# Training and score
learning_rate = [0.15, 0.2, 0.25]
max_depth = [15, 20, 25]

param_grid = {'learning_rate': learning_rate, 'max_depth': max_depth}

# Fitting
cv_lgbm = GridSearchCV(lgbm, param_grid, cv=10, n_jobs =1)
cv_lgbm.fit(X_train, y_train)

print("Best params:{}".format(cv_lgbm.best_params_))

# best params
best_lg = cv_lgbm.best_estimator_

# prediction
y_train_pred_lg = best_lg.predict(X_train)
y_test_pred_lg = best_lg.predict(X_test)

print("MSE train:{}".format(mean_squared_error(y_train, y_train_pred_lg)))
print("MSE test;{}".format(mean_squared_error(y_test, y_test_pred_lg)))

print("R2 score train:{}".format(r2_score(y_train, y_train_pred_lg)))
print("R2 score test:{}".format(r2_score(y_test, y_test_pred_lg)))
# Out:
# Best params:{'learning_rate': 0.15, 'max_depth': 25}
# MSE train:1.083809003506013
# MSE test;3.3448334245952154
# R2 score train:0.8817868321009381
# R2 score test:0.6111346726126745

# %%
run_id=list(range(300))
df_metrics=pd.DataFrame(run_id,columns=['run_id'])
df_metrics['feat_name'] = pd.Series(X_train.columns[0:300], index=dataframe.index) 
df_metrics['feat_type']=df_metrics.feat_name
df_metrics.replace({'feat_type': r'^lag_.*'}, {'feat_type': 'lag'}, regex=True,inplace=True)
df_metrics.replace({'feat_type': r'^rolling.*'}, {'feat_type': 'rolling'}, regex=True,inplace=True)
df_metrics['parameter'] = pd.Series(best_lg, index=dataframe.index) 
df_metrics['metric_name'] ="MSE" 
df_metrics['metric_val'] = pd.Series(pred_mse[:300], index=dataframe.index) 
df_metrics.to_csv("train.csv")


df_metrics
# Out:
#      run_id                          feat_name  ... metric_name metric_val
# 0         0                         lag_44_day  ...         MSE   0.836521
# 1         1                rolling3_lag_56_day  ...         MSE   0.220465
# 2         2                rolling7_lag_56_day  ...         MSE   0.211865
# 3         3                         lag_56_day  ...         MSE   1.901740
# 4         4                rolling3_lag_46_day  ...         MSE   0.841908
# ..      ...                                ...  ...         ...        ...
# 295     295  rolling84_lag_15_day_of_last_year  ...         MSE   0.214783
# 296     296               rolling84_lag_45_day  ...         MSE   0.103399
# 297     297       store_lag_9_day_of_last_year  ...         MSE   0.167058
# 298     298                          HOBBIES_1  ...         MSE   0.219598
# 299     299                               TX_3  ...         MSE   0.550920
#
# [300 rows x 6 columns]
