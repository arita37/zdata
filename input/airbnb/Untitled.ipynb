# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_parquet("/home/soheil/Soheil/lin-python/S/multi/data/output/airbnb/LGBMRegressor//features_store//dfX/features.parquet")

# %%
np.where(np.array(df.iloc[0,:]).astype('float32')>0)[0]
# Out:
# <ipython-input-49-1f956df93fd5>:1: RuntimeWarning: invalid value encountered in greater
#   np.where(np.array(df.iloc[0,:]).astype('float32')>0)
# (array([64, 65, 66, 68, 70]),)

# %%
df.columns[np.where(np.array(df.iloc[0,:]).astype('float32')>0)[0]]
# Out:
# <ipython-input-51-1155972f88b7>:1: RuntimeWarning: invalid value encountered in greater
#   df.columns[np.where(np.array(df.iloc[0,:]).astype('float32')>0)[0]]
# Index(['house_rules_svd_0', 'house_rules_svd_1', 'neighborhood_overview_svd_0',
#        'notes_svd_0', 'street_svd_0'],
#       dtype='object')

# %%
np.array(df.iloc[0,:]).astype('float32')
# Out:
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,  0.07226278,
# ...

# %%
df.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  271739  https://www.airbnb.com/rooms/271739  20181107122246   2018-11-07
# 1  250067  https://www.airbnb.com/rooms/250067  20181107122246   2018-11-07
#
#                                              name  \
# 0  X-Berg: central, quiet, bright, cosy and large
# 1              Great 2bd apt perfect for a couple
#
#                                              summary  \
# 0  In the heart of Kreuzberg, two minutes from th...
# 1                                                NaN
#
#                                                space  \
# 0  The guest room is 25-m2 in size and is located...
# 1  Enjoy your holidays in Berlin! Our beautiful 2...
#
#                                          description experiences_offered  \
# 0  In the heart of Kreuzberg, two minutes from th...                none
# 1  Enjoy your holidays in Berlin! Our beautiful 2...                none
#
# ...

# %%
colnum = [  "review_scores_communication", "review_scores_location", "review_scores_rating"         ]

# %%
df['notes'].apply(lambda x: pd.value_counts(x.split(' ')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-94871b622b6d> in <module>
# ----> 1 df[ 'notes'].apply(lambda x: pd.value_counts(x.split(' ')))
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-94871b622b6d> in <lambda>(x)
# ----> 1 df[ 'notes'].apply(lambda x: pd.value_counts(x.split(' ')))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df[['house_rules', 
    'neighborhood_overview', 'notes', 
    'street']].apply(str).apply(lambda x: pd.value_counts(x.split(' ')))
# Out:
#                               the    -  out...\n2  10pm  don't  control  \
# house_rules            229.0  2.0  2.0        1.0   1.0    1.0      1.0
# neighborhood_overview  249.0  2.0  NaN        NaN   NaN    NaN      NaN
# notes                  255.0  4.0  2.0        NaN   NaN    NaN      NaN
# street                  65.0  NaN  NaN        NaN   NaN    NaN      NaN
#
#                        NaN\n359  First  laundry,  ...  Germany\n360  \
# house_rules                 1.0    1.0       1.0  ...           NaN
# neighborhood_overview       NaN    NaN       NaN  ...           NaN
# notes                       NaN    NaN       NaN  ...           NaN
# street                      NaN    NaN       NaN  ...           1.0
#
#                        Germany\n2  Germany\n359  Germany\n4  street,  \
# house_rules                   NaN           NaN         NaN      NaN
# neighborhood_overview         NaN           NaN         NaN      NaN
# ...

# %%
pd.concat((df[['house_rules']],df[['notes']]),axis=1)
# Out:
#                                            house_rules  \
# 0    First Rule: Have Fun! Beside that: Please don'...
# 1    There's a lot of cool clubs and bars to go out...
# 2    ***Illegal file-sharing is strictly forbidden!...
# 3                                                  NaN
# 4    - NO SMOKING! (inside the flat) - After 10pm p...
# ..                                                 ...
# 357  Payment for laundry, cleaning etc. before Chec...
# 358                                                NaN
# 359  Be nice, keep noise under control (we don't wa...
# 360                                                NaN
# 361  Before booking please accept the 'all must fel...
#
#                                                  notes
# 0    The room / apartment is located in the rear ho...
# 1                                                  NaN
# 2                                                  NaN
# 3    Spend favorite district of Berliners to a free...
# ...

# %%
df[['house_rules']].concat(df[['notes']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-b5dc31b01a9d> in <module>
# ----> 1 df[['house_rules']].concat(df[['notes']])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'concat'
